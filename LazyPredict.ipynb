# %% [markdown]
# # Learning Lazy Predict
#
# Selecting the best model for your Machine Learning problem statement

# %%
# Importing Diabetes dataset
import pandas as pd
data = pd.read_csv("diabetes.csv")

# %%
#Installing Lazy Predict
! pip install lazypredict
# Out:
# ...
#      |████████████████████████████████| 6.8 MB 14.8 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 35.6 MB/s
# ...
#      |████████████████████████████████| 25.9 MB 911 bytes/s
# ...
#      |████████████████████████████████| 302 kB 45.8 MB/s
# ...
#      |████████████████████████████████| 269 kB 72.1 MB/s
# ...
#      |████████████████████████████████| 127.6 MB 6.8 kB/s
# ...
#      |████████████████████████████████| 14.5 MB 7.6 kB/s
# ...
#      |████████████████████████████████| 10.1 MB 14.6 MB/s
# ...
#      |████████████████████████████████| 248 kB 59.2 MB/s
# ...
#      |████████████████████████████████| 72 kB 679 kB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44635 sha256=424634000831f5bffe4c66cf1a4c428cd41bb1a96fc6e1fa2188be03f082bdcd
#   Stored in directory: /root/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
# Successfully built PyYAML
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
# ...

# %%
#Outcome is the dependent variable
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
# Splitting data
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

x = data.drop("Outcome", axis=1)
y = data.Outcome
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((614, 8), (154, 8), (614,), (154,))

# %%
# Lazy Classifier
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(x_train, x_test, y_train, y_test)

models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 18.35it/s]
#                                Accuracy  ...  Time Taken
# Model                                    ...
# QuadraticDiscriminantAnalysis      0.78  ...        0.02
# GaussianNB                         0.77  ...        0.02
# RidgeClassifierCV                  0.77  ...        0.02
# DecisionTreeClassifier             0.75  ...        0.02
# LinearDiscriminantAnalysis         0.76  ...        0.03
# RidgeClassifier                    0.76  ...        0.02
# LinearSVC                          0.75  ...        0.06
# LogisticRegression                 0.75  ...        0.03
# CalibratedClassifierCV             0.75  ...        0.14
# LGBMClassifier                     0.73  ...        0.08
# Perceptron                         0.73  ...        0.02
# PassiveAggressiveClassifier        0.73  ...        0.02
# ExtraTreesClassifier               0.74  ...        0.19
# AdaBoostClassifier                 0.73  ...        0.13
# ...

# %%
# Lazy Regressor
# importing Delany solubility dataset
df = pd.read_csv("Delany_solu_lazy.csv")
df.head()
#logS is the dependent variable
# Out:
#    MolLogP  MolWt  NumRotatableBonds  AromaticProportion  logS
# 0     2.60 167.85                  0                0.00 -2.18
# 1     2.38 133.41                  0                0.00 -2.00
# 2     2.59 167.85                  1                0.00 -1.74
# 3     2.03 133.41                  1                0.00 -1.48
# 4     2.92 187.38                  1                0.00 -3.04

# %%
X = df.drop(['logS'], axis=1)
Y = df.logS
#Y = dataset.iloc[:,-1]
Y
# Out:
# 0      -2.18
# 1      -2.00
# 2      -1.74
# 3      -1.48
# 4      -3.04
#         ...
# 1139    1.14
# 1140   -4.92
# 1141   -3.89
# 1142   -3.79
# 1143   -2.58
# Name: logS, Length: 1144, dtype: float64

# %%
X.shape, Y.shape
# Out:
# ((1144, 4), (1144,))

# %%
# Lazy Regressor
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y,test_size=.3,random_state =42)


X_train.shape, X_test.shape, y_train.shape, y_test.shape
clf = LazyRegressor(verbose=0,ignore_warnings=False, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

models
# Out:
#  24%|██▍       | 10/42 [00:00<00:01, 17.96it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range for family GammaDistribution
#  69%|██████▉   | 29/42 [00:03<00:02,  6.30it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range for family PoissonDistribution
# 100%|██████████| 42/42 [00:04<00:00, 10.27it/s]
#                                Adjusted R-Squared  R-Squared   RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.88       0.88   0.71        0.23
# RandomForestRegressor                        0.88       0.88   0.73        0.30
# LGBMRegressor                                0.87       0.87   0.75        0.10
# HistGradientBoostingRegressor                0.87       0.87   0.76        0.38
# BaggingRegressor                             0.86       0.87   0.76        0.05
# GradientBoostingRegressor                    0.86       0.87   0.76        0.18
# ...

# %% [markdown]
# # To learn more please look into Lazy predict mannual
